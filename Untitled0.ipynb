# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv("operational_excellence on_time_execution_LCL_Not_China.csv")
data_df = pd.DataFrame(data)
pd.set_option('display.max_columns', None)
data_df.head()
# Out:
#    Unnamed: 0 Ocean type category Ocean LCL subcategory  Shipment ID  \
# 0           1        coloaded_lcl      Shipco Transport      2994634
# 1           2        coloaded_lcl        other_coloader      3004735
# 2           3        coloaded_lcl      Shipco Transport      3053932
# 3           4        coloaded_lcl      Shipco Transport      3054381
# 4           5        coloaded_lcl      Shipco Transport      3031750
#
#   Tradelane Departure port Ocean LOC Final port Ocean LOC      Port pair  \
# 0      TPEB                    VNSGN                USNYC  VNSGN - USNYC
# 1      FEWB                    KRPUS                NLRTM  KRPUS - NLRTM
# 2      TPEB                    VNSGN                USLAX  VNSGN - USLAX
# 3      TAWB                    ITGOA                USNYC  ITGOA - USNYC
# 4      TPEB                    CNXMN                USNYC  CNXMN - USNYC
#
#   Departure Port Departed On Date OTP Promised Delivery Date  \
# 0                      2025-02-02                 2025-04-03
# 1                      2025-01-16                 2025-03-31
# 2                      2025-02-13                 2025-04-03
# 3                      2025-02-24                 2025-04-04
# 4                      2025-01-28                 2025-03-31
#
#   OTP Promised Delivery Week In Full Delivered On Date Primary Delay Stage  \
# 0                 2025-03-31                2025-04-03             On Time
# 1                 2025-03-31                2025-03-20             On Time
# 2                 2025-03-31                2025-03-31             On Time
# 3                 2025-03-31                2025-04-01             On Time
# 4                 2025-03-31                2025-03-17             On Time
#
#    Quoted Origin Total Days  Quoted Port to Port Days  \
# 0                      13.0                      53.0
# 1                      13.0                      64.0
# 2                      13.0                      39.0
# 3                      13.0                      39.0
# 4                      14.0                      55.0
#
#    Quoted Destination Total Days  Total Quoted Days  Actual Origin Total Days  \
# 0                            3.0                 69                       8.9
# 1                            4.0                 81                       8.1
# 2                            3.0                 55                       5.9
# 3                            5.0                 57                       0.1
# 4                            3.0                 72                      10.9
#
#    Actual Port to Port Days  Actual Destination Total Days  Total Actual Days  \
# 0                      57.3                            3.4               70.0
# 1                      60.9                            4.4               73.0
# 2                      40.9                           26.5               73.0
# 3                      52.8                            9.9               63.0
# 4                      42.0                            9.3               62.0
#
#    Delta quoted vs actual total days  Delta actual vs quoted origin days  \
# 0                                1.0                                -4.0
# 1                               -8.0                                -5.0
# 2                               18.0                                -7.0
# 3                                6.0                               -13.0
# 4                              -10.0                                -3.0
#
#    Delta actual vs quoted p2p days  Delta actual vs quoted destination days  \
# 0                              4.0                                      0.0
# 1                             -3.0                                      0.0
# 2                              2.0                                     23.0
# 3                             14.0                                      5.0
# 4                            -13.0                                      6.0
#
#   Origin on Time Performance Port to Port on Time Performance  \
# 0                     100.0%                             0.0%
# 1                     100.0%                           100.0%
# 2                     100.0%                           100.0%
# 3                     100.0%                             0.0%
# 4                     100.0%                           100.0%
#
#   Destination on Time Performance     OTP  Client ID
# 0                          100.0%  100.0%      93437
# 1                          100.0%  100.0%       9728
# 2                            0.0%  100.0%      82785
# 3                          100.0%  100.0%      46128
# 4                            0.0%  100.0%      58554

# %%
data_df = data_df.drop(columns=['Unnamed: 0',
                                 'Departure port Ocean LOC',
                      'Final port Ocean LOC',
                      'In Full Delivered On Date',
                      'Primary Delay Stage',
                      'Quoted Origin Total Days',
                      'Quoted Port to Port Days',
                      'Quoted Destination Total Days',
                      'Total Quoted Days',
                      'Actual Origin Total Days',
                      'Actual Port to Port Days',
                      'Actual Destination Total Days',
                      'Delta quoted vs actual total days',
                      'Delta actual vs quoted origin days',
                      'Delta actual vs quoted p2p days',
                      'Delta actual vs quoted destination days',
                      'Origin on Time Performance',
                      'Port to Port on Time Performance',
                      'Destination on Time Performance',
                      'OTP',
                      'Shipment ID',
                      'Client ID'])

# %%
data_df.head()
# Out:
#   Ocean type category Ocean LCL subcategory Tradelane      Port pair  \
# 0        coloaded_lcl      Shipco Transport      TPEB  VNSGN - USNYC
# 1        coloaded_lcl        other_coloader      FEWB  KRPUS - NLRTM
# 2        coloaded_lcl      Shipco Transport      TPEB  VNSGN - USLAX
# 3        coloaded_lcl      Shipco Transport      TAWB  ITGOA - USNYC
# 4        coloaded_lcl      Shipco Transport      TPEB  CNXMN - USNYC
#
#   Departure Port Departed On Date OTP Promised Delivery Date  \
# 0                      2025-02-02                 2025-04-03
# 1                      2025-01-16                 2025-03-31
# 2                      2025-02-13                 2025-04-03
# 3                      2025-02-24                 2025-04-04
# 4                      2025-01-28                 2025-03-31
#
#   OTP Promised Delivery Week  Total Actual Days
# 0                 2025-03-31               70.0
# 1                 2025-03-31               73.0
# 2                 2025-03-31               73.0
# 3                 2025-03-31               63.0
# 4                 2025-03-31               62.0

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3769 entries, 0 to 3768
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ocean type category              3769 non-null   object
#  1   Ocean LCL subcategory            3769 non-null   object
#  2   Tradelane                        3769 non-null   object
#  3   Port pair                        3769 non-null   object
#  4   Departure Port Departed On Date  3767 non-null   object
#  5   OTP Promised Delivery Date       3769 non-null   object
#  6   OTP Promised Delivery Week       3769 non-null   object
#  7   Total Actual Days                3565 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 235.7+ KB

# %%
data_df = data_df.dropna()
data_df.head()
# Out:
#   Ocean type category Ocean LCL subcategory Tradelane      Port pair  \
# 0        coloaded_lcl      Shipco Transport      TPEB  VNSGN - USNYC
# 1        coloaded_lcl        other_coloader      FEWB  KRPUS - NLRTM
# 2        coloaded_lcl      Shipco Transport      TPEB  VNSGN - USLAX
# 3        coloaded_lcl      Shipco Transport      TAWB  ITGOA - USNYC
# 4        coloaded_lcl      Shipco Transport      TPEB  CNXMN - USNYC
#
#   Departure Port Departed On Date OTP Promised Delivery Date  \
# 0                      2025-02-02                 2025-04-03
# 1                      2025-01-16                 2025-03-31
# 2                      2025-02-13                 2025-04-03
# 3                      2025-02-24                 2025-04-04
# 4                      2025-01-28                 2025-03-31
#
#   OTP Promised Delivery Week  Total Actual Days
# 0                 2025-03-31               70.0
# 1                 2025-03-31               73.0
# 2                 2025-03-31               73.0
# 3                 2025-03-31               63.0
# 4                 2025-03-31               62.0

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3565 entries, 0 to 3768
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ocean type category              3565 non-null   object
#  1   Ocean LCL subcategory            3565 non-null   object
#  2   Tradelane                        3565 non-null   object
#  3   Port pair                        3565 non-null   object
#  4   Departure Port Departed On Date  3565 non-null   object
#  5   OTP Promised Delivery Date       3565 non-null   object
#  6   OTP Promised Delivery Week       3565 non-null   object
#  7   Total Actual Days                3565 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 250.7+ KB

# %%
data_df[['Departure Port Departed On Date',
         'OTP Promised Delivery Date',
         'OTP Promised Delivery Week']] = data_df[['Departure Port Departed On Date',
                                                   'OTP Promised Delivery Date',
                                                   'OTP Promised Delivery Week']].apply(pd.to_datetime)

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3565 entries, 0 to 3768
# Data columns (total 8 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ocean type category              3565 non-null   object
#  1   Ocean LCL subcategory            3565 non-null   object
#  2   Tradelane                        3565 non-null   object
#  3   Port pair                        3565 non-null   object
#  4   Departure Port Departed On Date  3565 non-null   datetime64[ns]
#  5   OTP Promised Delivery Date       3565 non-null   datetime64[ns]
#  6   OTP Promised Delivery Week       3565 non-null   datetime64[ns]
#  7   Total Actual Days                3565 non-null   float64
# dtypes: datetime64[ns](3), float64(1), object(4)
# memory usage: 250.7+ KB

# %%
data_df.head()
# Out:
#   Ocean type category Ocean LCL subcategory Tradelane      Port pair  \
# 0        coloaded_lcl      Shipco Transport      TPEB  VNSGN - USNYC
# 1        coloaded_lcl        other_coloader      FEWB  KRPUS - NLRTM
# 2        coloaded_lcl      Shipco Transport      TPEB  VNSGN - USLAX
# 3        coloaded_lcl      Shipco Transport      TAWB  ITGOA - USNYC
# 4        coloaded_lcl      Shipco Transport      TPEB  CNXMN - USNYC
#
#   Departure Port Departed On Date OTP Promised Delivery Date  \
# 0                      2025-02-02                 2025-04-03
# 1                      2025-01-16                 2025-03-31
# 2                      2025-02-13                 2025-04-03
# 3                      2025-02-24                 2025-04-04
# 4                      2025-01-28                 2025-03-31
#
#   OTP Promised Delivery Week  Total Actual Days
# 0                 2025-03-31               70.0
# 1                 2025-03-31               73.0
# 2                 2025-03-31               73.0
# 3                 2025-03-31               63.0
# 4                 2025-03-31               62.0

# %% [markdown]
# numerical value scale or normalize it
# categorical values one-hot encoding or embedding
# extract year month and day from the date

# %%
data_df['Departure_dayofweek'] = data_df['Departure Port Departed On Date'].dt.dayofweek
data_df['Promised_Delive_dayofweek'] = data_df['Departure Port Departed On Date'].dt.dayofweek
data_df['Promised_Delivery_dayofweek'] = data_df['Departure Port Departed On Date'].dt.dayofweek

# %%
modelling_data_df = data_df.copy()
modelling_data_df = modelling_data_df.drop(columns=[
    "Departure Port Departed On Date",
    "OTP Promised Delivery Date",
    "OTP Promised Delivery Week"
])
modelling_data_df.head(10)
# Out:
#   Ocean type category Ocean LCL subcategory Tradelane      Port pair  \
# 0        coloaded_lcl      Shipco Transport      TPEB  VNSGN - USNYC
# 1        coloaded_lcl        other_coloader      FEWB  KRPUS - NLRTM
# 2        coloaded_lcl      Shipco Transport      TPEB  VNSGN - USLAX
# 3        coloaded_lcl      Shipco Transport      TAWB  ITGOA - USNYC
# 4        coloaded_lcl      Shipco Transport      TPEB  CNXMN - USNYC
# 5        coloaded_lcl      Shipco Transport      TPEB  VNHPH - USNYC
# 6        coloaded_lcl      Shipco Transport      TPEB  INNSA - USHOU
# 7        coloaded_lcl      Shipco Transport      TPEB  INNSA - USNYC
# 8            flxt_lcl        flxt_lcl_child      TPEB  TWKHH - USLAX
# 9            flxt_lcl        flxt_lcl_child      TPEB  CNYTN - USLAX
#
#    Total Actual Days  Departure_dayofweek  Promised_Delive_dayofweek  \
# 0               70.0                    6                          6
# 1               73.0                    3                          3
# 2               73.0                    3                          3
# 3               63.0                    0                          0
# 4               62.0                    1                          1
# 5               76.0                    2                          2
# 6               79.0                    6                          6
# 7               53.0                    1                          1
# 8               38.0                    5                          5
# 9               31.0                    1                          1
#
#    Promised_Delivery_dayofweek
# 0                            6
# 1                            3
# 2                            3
# 3                            0
# 4                            1
# 5                            2
# 6                            6
# 7                            1
# 8                            5
# 9                            1

# %%
cat_columns = ["Ocean type category","Ocean LCL subcategory","Tradelane"]
numerical_columns = ['Departure_dayofweek'	,'Promised_Delive_dayofweek'	,'Promised_Delivery_dayofweek']

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
import numpy as np
# creating dummies for first three columns
X_cat_columns = OneHotEncoder(sparse_output=False, handle_unknown='ignore').fit_transform(modelling_data_df[cat_columns])

# Label encode the high-cardinality column
X_port_pair = LabelEncoder().fit_transform(modelling_data_df["Port pair"]).reshape(-1, 1)

# Convert multiple numerical columns to numpy array
X_num = modelling_data_df[numerical_columns].to_numpy()

# Concatenate all parts
X = np.concatenate([X_cat_columns, X_port_pair, X_num], axis=1)

# Get target variable
y = modelling_data_df['Total Actual Days'].to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
scaler = StandardScaler()

# %%
X_scaler = scaler.fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
rf_model = RandomForestClassifier(n_estimators=500, random_state=0)

# %%
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
predictions = rf_model.predict(X_test_scaled)

# %%
from sklearn.metrics import  accuracy_score

acc_score = accuracy_score(y_test, predictions)
acc_score
# Out:
# 0.06614349775784753
